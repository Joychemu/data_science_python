# %%
import pandas as pd

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set_style('darkgrid')
sns.set(font_scale=1.5)

# %%
mov_df=pd.read_csv("data/IMDb movies.csv")

# %%
mov_df.head()
# Out:
#   imdb_title_id                                              title  \
# 0     tt0000574                        The Story of the Kelly Gang
# 1     tt0001892                                     Den sorte drøm
# 2     tt0002101                                          Cleopatra
# 3     tt0002130                                          L'Inferno
# 4     tt0002199  From the Manger to the Cross; or, Jesus of Naz...
#
#                                       original_title  year date_published  \
# 0                        The Story of the Kelly Gang  1906     1906-12-26
# 1                                     Den sorte drøm  1911     1911-08-19
# 2                                          Cleopatra  1912     1912-11-13
# 3                                          L'Inferno  1911     1911-03-06
# 4  From the Manger to the Cross; or, Jesus of Naz...  1912           1913
#
#                        genre  duration           country language  \
# ...

# %%
mov_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81273 entries, 0 to 81272
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          81273 non-null  object
#  1   title                  81273 non-null  object
#  2   original_title         81273 non-null  object
#  3   year                   81273 non-null  int64
#  4   date_published         81273 non-null  object
#  5   genre                  81273 non-null  object
#  6   duration               81273 non-null  int64
#  7   country                81234 non-null  object
#  8   language               80518 non-null  object
#  9   director               81200 non-null  object
#  10  writer                 79780 non-null  object
#  11  production_company     76948 non-null  object
#  12  actors                 81207 non-null  object
#  13  description            78843 non-null  object
# ...

# %%
mov_df.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
mov_df.shape
# Out:
# (81273, 22)

# %%
temp_df=mov_df.append(mov_df)
temp_df.shape
# Out:
# (162546, 22)

# %%
temp_df=temp_df.drop_duplicates()
temp_df.shape
# Out:
# (81273, 22)

# %%
temp_df.drop_duplicates(inplace=True)
temp_df.shape
# Out:
# (81273, 22)

# %%
temp_df.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
temp_df.rename(columns={
        'usa_gross_income': 'usa_gross', 
        'worlwide_gross_income':'worldwide_gross',
        'reviews_from_users':'users_review',
        'reviews_from_critics':'critics_review'
}, inplace=True)


temp_df.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross', 'worldwide_gross', 'metascore', 'users_review',
#        'critics_review'],
#       dtype='object')

# %%
mov_df.columns = [col.lower() for col in mov_df]

mov_df.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
temp_df.isnull()
# Out:
#        imdb_title_id  title  original_title   year  date_published  genre  \
# 0              False  False           False  False           False  False
# 1              False  False           False  False           False  False
# 2              False  False           False  False           False  False
# 3              False  False           False  False           False  False
# 4              False  False           False  False           False  False
# ...              ...    ...             ...    ...             ...    ...
# 81268          False  False           False  False           False  False
# 81269          False  False           False  False           False  False
# 81270          False  False           False  False           False  False
# 81271          False  False           False  False           False  False
# 81272          False  False           False  False           False  False
#
#        duration  country  language  director  ...  actors  description  \
# ...

# %%
temp_df.isnull().sum()
# Out:
# imdb_title_id                0
# title                        0
# original_title               0
# year                         0
# date_published               0
# genre                        0
# duration                     0
# country                     39
# language                   755
# director                    73
# writer                    1493
# production_company        4325
# actors                      66
# description               2430
# avg_vote                     0
# votes                        0
# budget                   58469
# usa_gross_income         66179
# worlwide_gross_income    51381
# metascore                68551
# reviews_from_users        7077
# reviews_from_critics     10987
# dtype: int64

# %%
temp_df.dropna()
# Out:
#       imdb_title_id                            title  \
# 488       tt0017136                       Metropolis
# 1005      tt0021749                      City Lights
# 2336      tt0027977                     Modern Times
# 2687      tt0029583  Snow White and the Seven Dwarfs
# 3100      tt0031381               Gone with the Wind
# ...             ...                              ...
# 80665     tt8772262                        Midsommar
# 80858     tt9024106                        Unplanned
# 80908     tt9082020                Cold Blood Legacy
# 80946     tt9134216                Playing with Fire
# 81059     tt9354944                             Jexi
#
#                         original_title  year date_published  \
# 488                         Metropolis  1927     1927-02-06
# 1005                       City Lights  1931     1931-08-21
# 2336                      Modern Times  1936     1936-10-16
# 2687   Snow White and the Seven Dwarfs  1937     1938-07-08
# ...

# %%
temp_df.dropna(axis=1)
# Out:
#       imdb_title_id                                              title  \
# 0         tt0000574                        The Story of the Kelly Gang
# 1         tt0001892                                     Den sorte drøm
# 2         tt0002101                                          Cleopatra
# 3         tt0002130                                          L'Inferno
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# ...             ...                                                ...
# 81268     tt9903716                                             Jessie
# 81269     tt9905412                                              Ottam
# 81270     tt9905462                                          Pengalila
# 81271     tt9911774                          Padmavyuhathile Abhimanyu
# 81272     tt9914286                                  Sokagin Çocuklari
#
#                                           original_title  year date_published  \
# ...

# %%
temp_df.shape
# Out:
# (81273, 22)

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81273 entries, 0 to 81272
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          81273 non-null  object
#  1   title                  81273 non-null  object
#  2   original_title         81273 non-null  object
#  3   year                   81273 non-null  int64
#  4   date_published         81273 non-null  object
#  5   genre                  81273 non-null  object
#  6   duration               81273 non-null  int64
#  7   country                81234 non-null  object
#  8   language               80518 non-null  object
#  9   director               81200 non-null  object
#  10  writer                 79780 non-null  object
#  11  production_company     76948 non-null  object
#  12  actors                 81207 non-null  object
#  13  description            78843 non-null  object
# ...

# %%
cty=(list(mov_df['country'].mode()))[0]
cty
# Out:
# 'USA'

# %%
c=list(temp_df['country'].mode())
c
# Out:
# ['USA']

# %%
cc=c[0]
cc
# Out:
# 'USA'

# %%
temp_df['country'].fillna(cc,inplace=True)
temp_df['country'].isnull().sum()
# Out:
# 0

# %%
gn=temp_df[['genre','users_review']]
gn[(gn['genre']=='Drama, History')]
# Out:
#                 genre  users_review
# 2      Drama, History     24.000000
# 6      Drama, History      6.000000
# 32     Drama, History      8.000000
# 73     Drama, History    105.000000
# 151    Drama, History      8.000000
# ...               ...           ...
# 80137  Drama, History     43.753194
# 80429  Drama, History      2.000000
# 80476  Drama, History      1.000000
# 80793  Drama, History      5.000000
# 81014  Drama, History    305.000000
#
# [358 rows x 2 columns]

# %%
gns = list(set(gn['genre']))
gnm =[]
for i in range (0,len(gns)):
    
    gnr=gn[gn['genre']==gns[i]]
    gnm.append(gnr.mean())
gnm
# Out:
# [users_review    8.0
#  dtype: float64,
#  users_review    80.0
#  dtype: float64,
#  users_review    141.076226
#  dtype: float64,
#  users_review    10.0
#  dtype: float64,
#  users_review    49.5
#  dtype: float64,
#  users_review    43.753194
#  dtype: float64,
#  users_review    25.917731
#  dtype: float64,
#  users_review    2.0
#  dtype: float64,
#  users_review    36.25
#  dtype: float64,
#  users_review    8.0
#  dtype: float64,
#  users_review    32.0
#  dtype: float64,
#  users_review    3.0
#  dtype: float64,
#  users_review    1.5
#  dtype: float64,
#  users_review    85.108029
#  dtype: float64,
#  users_review    62.526936
#  dtype: float64,
#  users_review    31.0
#  dtype: float64,
#  users_review    42.5
#  dtype: float64,
#  users_review    16.5
#  dtype: float64,
#  users_review    11.333333
#  dtype: float64,
#  users_review    45.818182
#  dtype: float64,
#  users_review    20.375
#  dtype: float64,
#  users_review    4.0
#  dtype: float64,
# ...

# %% [markdown]
# ### 1. Find the mean of review_from_users for each unique genre
# e.g action,drama=7.2
# thriller =7.8
# ### 2. Replace each null value with its corresponding mean

# %%
temp_df.isnull().sum()
# Out:
# imdb_title_id                0
# title                        0
# original_title               0
# year                         0
# date_published               0
# genre                        0
# duration                     0
# country                      0
# language                   755
# director                    73
# writer                    1493
# production_company        4325
# actors                      66
# description               2430
# avg_vote                     0
# votes                        0
# budget                   58469
# usa_gross_income         66179
# worlwide_gross_income    51381
# metascore                68551
# reviews_from_users        7077
# reviews_from_critics     10987
# dtype: int64

# %%
lang=(list(temp_df['language'].mode()))[0]
lang
# Out:
# 'English'

# %%
temp_df['language'].fillna(lang, inplace=True)

# %%
dr=(list(temp_df['director'].mode()))[0]
dr
# Out:
# 'Michael Curtiz'

# %%
temp_df['director'].fillna(dr, inplace=True)

# %%
wr=(list(temp_df['writer'].mode()))[0]
wr
# Out:
# 'Jing Wong'

# %%
temp_df['writer'].fillna(wr, inplace=True)

# %%
pc=(list(temp_df['production_company'].mode()))[0]
pc
# Out:
# 'Metro-Goldwyn-Mayer (MGM)'

# %%
temp_df['production_company'].fillna(pc, inplace=True)

# %%
ac=(list(temp_df['actors'].mode()))[0]
ac
# Out:
# 'Nobuyo Ôyama, Noriko Ohara, Michiko Nomura, Kaneta Kimotsuki, Kazuya Tatekabe'

# %%
temp_df['actors'].fillna(ac, inplace=True)

# %%
desc=(list(temp_df['description'].mode()))[0]
desc
# Out:
# 'The story of'

# %%
temp_df['description'].fillna(desc, inplace=True)

# %%
bd=(list(temp_df['budget'].mode()))[0]
bd
# Out:
# '$ 1000000'

# %%
temp_df['budget'].fillna(bd, inplace=True)

# %%
usg=(list(temp_df['usa_gross'].mode()))[0]
usg
# Out:
# '$ 1000000'

# %%
temp_df['usa_gross'].fillna(usg, inplace=True)

# %%
wwg=(list(temp_df['worldwide_gross'].mode()))[0]
wwg
# Out:
# '$ 8144'

# %%
temp_df['worldwide_gross'].fillna(wwg, inplace=True)

# %%
met=temp_df['metascore']
met_mean=met.mean()
met_mean
# Out:
# 55.76269454488288

# %%
met.fillna(met_mean, inplace=True)

# %%
urev=temp_df['users_review']
urev_mean=urev.mean()
urev_mean
# Out:
# 43.75319424227721

# %%
urev.fillna(urev_mean, inplace=True)

# %%
crirev=temp_df['critics_review']
crirev_mean=crirev.mean()
crirev_mean
# Out:
# 27.992758159519678

# %%
crirev.fillna(crirev_mean, inplace=True)

# %%
temp_df.isnull().sum()
# Out:
# imdb_title_id         0
# title                 0
# original_title        0
# year                  0
# date_published        0
# genre                 0
# duration              0
# country               0
# language              0
# director              0
# writer                0
# production_company    0
# actors                0
# description           0
# avg_vote              0
# votes                 0
# budget                0
# usa_gross             0
# worldwide_gross       0
# metascore             0
# users_review          0
# critics_review        0
# dtype: int64

# %%
temp_df.describe()
# Out:
#                year      duration      avg_vote         votes     metascore  \
# count  81273.000000  81273.000000  81273.000000  8.127300e+04  81273.000000
# mean    1993.007210    100.565981      5.926587  9.421771e+03     55.762695
# std       23.992284     25.320189      1.243315  5.220245e+04      7.025396
# min     1906.000000     40.000000      1.000000  9.900000e+01      1.000000
# 25%     1979.000000     88.000000      5.200000  2.060000e+02     55.762695
# 50%     2002.000000     96.000000      6.100000  4.950000e+02     55.762695
# 75%     2012.000000    108.000000      6.800000  1.865000e+03     55.762695
# max     2019.000000   3360.000000     10.000000  2.159628e+06    100.000000
#
#        users_review  critics_review
# count  81273.000000    81273.000000
# mean      43.753194       27.992758
# std      152.782989       54.596372
# min        1.000000        1.000000
# 25%        4.000000        4.000000
# 50%       11.000000       11.000000
# ...

# %%
temp_df.corr()
# Out:
#                     year  duration  avg_vote     votes  metascore  \
# year            1.000000  0.150164 -0.213843  0.061409  -0.039137
# duration        0.150164  1.000000  0.221752  0.111327   0.070974
# avg_vote       -0.213843  0.221752  1.000000  0.164838   0.214509
# votes           0.061409  0.111327  0.164838  1.000000   0.182566
# metascore      -0.039137  0.070974  0.214509  0.182566   1.000000
# users_review    0.066026  0.112797  0.136555  0.791088   0.115711
# critics_review  0.137550  0.107008  0.181166  0.673235   0.184007
#
#                 users_review  critics_review
# year                0.066026        0.137550
# duration            0.112797        0.107008
# avg_vote            0.136555        0.181166
# votes               0.791088        0.673235
# metascore           0.115711        0.184007
# users_review        1.000000        0.692670
# critics_review      0.692670        1.000000

# %%
gn=temp_df['genre'].unique()
gn
# Out:
# array(['Biography, Crime, Drama', 'Drama', 'Drama, History', ...,
#        'Crime, Mystery, Western', 'Adventure, History, Sci-Fi',
#        'Animation, Music'], dtype=object)

# %%
genre_counts = temp_df['genre'].value_counts()
temp_df2 = pd.DataFrame({'genre_type':genre_counts }, 
                     index = ['Biography, Crime, Drama', 'Drama', 'Drama, History', ...,
       'Crime, Mystery, Western', 'Adventure, History, Sci-Fi',
       'Animation, Music']
                   )
temp_df2.plot.pie(y='genre_type', figsize=(20,20), autopct='%1.1f%%')

# %%
criticsrev_mean=temp_df['critics_review'].mean()

criticsrev_mean
# Out:
# 27.992758159520463

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(20,10))
ax = sns.countplot(x='country', data=temp_df)
